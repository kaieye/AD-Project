# %%
import pandas as pd

# %%
data = list(pd.read_csv('label.csv').iloc[:,0])

# %%
data2 = pd.read_csv('ADNI1.csv')

# %%
for i in range(data2.shape[0]):
    data2.iloc[i,1] = data2.iloc[i,1][5:15]

# %%
data2
# Out:
#                         path    filename  age  gender  education  hispanic  \
# 0    /gemini/data-2/ADNInpy/  002_S_0295   85    male         18         2
# 1    /gemini/data-2/ADNInpy/  002_S_0413   77  female         16         2
# 2    /gemini/data-2/ADNInpy/  002_S_0559   79    male         16         2
# 3    /gemini/data-2/ADNInpy/  002_S_0619   78    male         12         2
# 4    /gemini/data-2/ADNInpy/  002_S_0685   90  female         16         2
# ..                       ...         ...  ...     ...        ...       ...
# 762  /gemini/data-2/ADNInpy/  941_S_1202   78    male         18         2
# 763  /gemini/data-2/ADNInpy/  941_S_1203   84    male         15         2
# 764  /gemini/data-2/ADNInpy/  941_S_1295   77    male         16         2
# 765  /gemini/data-2/ADNInpy/  941_S_1311   69    male         12         2
# 766  /gemini/data-2/ADNInpy/  941_S_1363   70  female         12         2
#
# ...
