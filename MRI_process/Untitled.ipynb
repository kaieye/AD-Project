# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.load('folder_outcomes/NACC491144_13122110752436604430000019031217553086400000025.npy')
plt.subplot(1, 3, 1)
plt.imshow(data[100, :, :],cmap='gray')
plt.subplot(1, 3, 2)
plt.imshow(data[:, 100, :],cmap='gray')
plt.subplot(1, 3, 3)
plt.imshow(data[:, :, 100],cmap='gray')
plt.tight_layout()
plt.savefig('processed_npy.jpg')

# %%
data = np.load('autodl-nas/origin_jpg/NACC491144_13122110752436604430000019031217553086400000025.npy')
plt.subplot(1, 3, 1)
plt.imshow(data[100, :, :],cmap='gray')
plt.subplot(1, 3, 2)
plt.imshow(data[:, 100, :],cmap='gray')
plt.subplot(1, 3, 3)
plt.imshow(data[:, :, 100],cmap='gray')
plt.tight_layout()
plt.savefig('ori_npy.jpg')

# %%
import nibabel as nib
data = nib.load('processed_NACC733752.nii').get_fdata()
print(data.shape)
plt.subplot(1, 3, 1)
plt.imshow(data[data.shape[0]//2, :, :],cmap='gray')
plt.subplot(1, 3, 2)
plt.imshow(data[:, data.shape[1]//2, :],cmap='gray')
plt.subplot(1, 3, 3)
plt.imshow(data[:, :, data.shape[2]//2],cmap='gray')
plt.tight_layout()
plt.savefig('pro.jpg')
# Out:
# (113, 137, 113)

# %%
import nibabel as nib
data = nib.load('processed/scans/NACC491144_13122110752436604430000019031217553086400000025.nii').get_fdata()
print(data.shape)
plt.subplot(1, 3, 1)
plt.imshow(data[100, :, :],cmap='gray')
plt.subplot(1, 3, 2)
plt.imshow(data[:, 100, :],cmap='gray')
plt.subplot(1, 3, 3)
plt.imshow(data[:, :, 100],cmap='gray')
plt.tight_layout()
plt.savefig('me.jpg')
# Out:
# (182, 218, 182)

# %%
import nibabel as nib
data = nib.load('processed/scans_uniform/NACC491144_13122110752436604430000019031217553086400000025.nii').get_fdata()
print(data.shape)
plt.subplot(1, 3, 1)
plt.imshow(data[100, :, :],cmap='gray')
plt.subplot(1, 3, 2)
plt.imshow(data[:, 100, :],cmap='gray')
plt.subplot(1, 3, 3)
plt.imshow(data[:, :, 100],cmap='gray')
plt.tight_layout()
plt.savefig('123.jpg')
# Out:
# (182, 218, 182)

# %%
data = np.load('ADNI_941_S_1311_MR_MPR.npy')

# %%
data.shape
# Out:
# (192, 192, 160)

# %%
import os
listdir = os.listdir('/gemini/code/NACC_processed_nii/images_past')
for i in range(len(listdir)):
    listdir[i] = listdir[i][:-3]
listdir_img = os.listdir('/gemini/code/NACC_processed_nii/images/')
for i in range(len(listdir_img)):
    listdir_img[i] = listdir_img[i][:-3]

# %%
len(listdir_img)
# Out:
# 607

# %%
for i in listdir:
    if i in listdir_img:
        os.remove('/gemini/code/NACC_processed_nii/scans/'+i+'nii')
    # data = np.load('/root/autodl-fs/NACC_npy/'+i,allow_pickle=True)
    # if data.shape[0] <181 or data.shape[1] < 217 or data.shape[2] < 181:
    #     os.remove('/root/autodl-fs/NACC_nii/'+i[:-3]+'nii')

# %%
listdir = os.listdir('/root/autodl-fs/NACC_nii/')

# %%
for i in listdir:
    if i.endswith('npy'):
        data = np.load('/root/autodl-fs/NACC_npy/'+i,allow_pickle=True)
        print(data.shape)
# Out:
# (256, 256, 24)
# (256, 256, 48)
# (256, 256, 176)
# (256, 256, 92)
# (256, 256, 35)
# (320, 320, 104)
# (256, 256, 92)
# (176, 240, 256)
# (220, 256, 160)
# (256, 256, 35)
# (512, 512, 176)
# (512, 512, 176)
# (176, 240, 256)
# (256, 256, 48)
# (192, 256, 256)
# (512, 512, 144)
# (256, 124, 256)
# (220, 256, 160)
# (512, 512, 30)
# (300, 320, 208)
# (220, 256, 160)
# (256, 256, 35)
# (256, 256, 162)
# (256, 256, 92)
# (220, 256, 160)
# (256, 124, 256)
# (256, 256, 176)
# (220, 256, 160)
# (220, 256, 160)
# (256, 256, 92)
# (256, 256, 92)
# (176, 240, 256)
# (320, 320, 104)
# (256, 256, 176)
# (512, 512, 144)
# (256, 256, 92)
# (288, 320, 23)
# (256, 256, 92)
# (256, 256, 35)
# (512, 512, 176)
# (136, 256, 256)
# (320, 320, 104)
# (176, 240, 256)
# (256, 256, 162)
# (256, 256, 48)
# (176, 240, 256)
# (220, 256, 160)
# (228, 256, 56)
# (512, 512, 144)
# (256, 256, 48)
# (512, 512, 144)
# KeyboardInterrupt
